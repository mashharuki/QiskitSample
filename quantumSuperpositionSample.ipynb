# %%
# 必要なライブラリをインポートする。
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.tools.visualization import plot_histogram

# %%
# 量子ビットを用意する。
qc = QuantumCircuit(1, 1)
# 量子ゲートを設置する。
qc.h(0)
qc.measure(0, 0)
qc.draw('mpl')

# マシンを選択して実行する。
backend = Aer.get_backend('qasm_simulator')
# ジョブを実行する
job = execute(qc, backend=backend, shots=1024)
cal_results=job.result()

# %%
# 結果を取得して描画&プロットする。
answer = cal_results.get_counts()
print(answer)
plot_histogram(answer)
# Out:
# {'0': 521, '1': 503}

# %%
# 3量子ビットによる重ね合わせ
n = 3
qc = QuantumCircuit(n, n)
# アダマールゲートを配置する。
for i in range(n) :
    qc.h(i)
    qc.measure(i, i)
    
# マシンを選択して実行する。
backend = Aer.get_backend('qasm_simulator')
# ジョブを実行する
job = execute(qc, backend=backend, shots=1024)
cal_results=job.result()

# %%
# 結果を取得して描画&プロットする。
answer = cal_results.get_counts()
print(answer)
plot_histogram(answer)
# Out:
# {'101': 134, '111': 126, '011': 121, '010': 131, '000': 127, '100': 128, '110': 139, '001': 118}
